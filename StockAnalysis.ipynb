# %% [markdown]
# # Stock Analysis

# %% [markdown]
# ### setting up resued code

# %%
#pip install alpha_vantage

# %%
import pandas as pd
from alpha_vantage.timeseries import TimeSeries

# %%
api_key = 'JOAOIVTNEKIG83KH'
ts = TimeSeries(key=api_key, output_format='pandas')

# %% [markdown]
# ## Overall Idea
# I will use the basic idea of buy low sell high
#
# in order to do that I will get the average closing price from the last 100 days, the last 30 days and last day on the market. I will use these 3 data points as markers to see how the stock is doing.
#
# There are 3 possible outcomes:
#
# - If the 100 day average is greater than the 30 day average I assume it will go up and I will buy when it is low
# - If the 100 day average is lower than the 30 day average and the last days closing price was up I assume it is too high and the stock will come down so I will sell high
# - If the 30 day average is higher than the 100 day average but the last day was below the 30 day average I cant conclude much so I will either hold if i have it or wait another day.
#
#
# ### week 2
#
# I changed my analysis section of my code to work off points now.
# - If the 100 day average is higher than the month average I give the stock a point otherwise I take a point away.
# - if the last day is lower than the month average I give the stock a point otherwise I take a point away.
# - if the stock grew last year within this month I give the stock a point otherwise I take a point way.
# - if the points are positive I buy if they are negative I sell if they are nutural I do nothing.
#
# I am also taking into consideration Walmart stock
#
# ### week 3
# I added more criteria to my analysis now:
# - I take into consideration 2 and 3 years ago from t
# - if this month from 1 2 and 3 years ago all ended higher than it started I give 2 points because there is reliable data to show that at this time the stock goes up.

# %% [markdown]
# ### Testing NKE

# %%
data, meta_data = ts.get_daily(symbol='NKE', outputsize='full')

close_data = data['4. close']

day = close_data[1]

i=1
avg = 0
while i<100:
    avg = close_data[i] + avg
    i = i+1
avg = avg/100
print("Nike 100 day average:", avg)


i=1
month = 0
while i<30:
    month = close_data[i] + month
    i = i+1
month = month/30
print("Nike 30 day average:", month)


yr = close_data[335] - close_data[365]
print("Nike diff from last year: ", yr)


yr2 = close_data[700] - close_data[730]
print("Nike diff from 2 years: ", yr2)


yr3 = close_data[1065] - close_data[1095]
print("Nike diff from 3 years: ", yr3)


points = 0
if(avg > month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if(day < month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if (yr > 0 and yr2 > 0 and yr3 > 0):
    points = points + 2
    print (points)
elif ((yr > 0 and yr2 > 0) or (yr2 > 0 and yr3 > 0) or (yr > 0 and yr3 > 0)):
    points = points + 1
    print (points)
elif (yr > 0 or yr2 > 0 or yr3 >0):
    print("null")
else:
    points = points - 1
    print (points)
    
    
    
print ("total",points)
if points > 0:
    print("buy NKE")
elif points < 0:
    print("sell NKE")
else:
    print("hold NKE")
# Out:
# Nike 100 day average: 162.07950000000005
# Nike 30 day average: 163.609
# Nike diff from last year:  -0.980000000000004
# Nike diff from 2 years:  8.75
# Nike diff from 3 years:  -5.640000000000001
# -1
# -2
# null
# total -2
# sell NKE

# %% [markdown]
# ### Testing GOOG

# %%
data, meta_data = ts.get_daily(symbol='GOOG', outputsize='full')

close_data = data['4. close']

day = close_data[1]

i=1
avg = 0
while i<100:
    avg = close_data[i] + avg
    i = i+1
avg = avg/100
print("GOOG 100 day average:", avg)


i=1
month = 0
while i<30:
    month = close_data[i] + month
    i = i+1
month = month/30
print("GOOG 30 day average:", month)


yr = close_data[335] - close_data[365]
print("GOOG diff from last year: ", yr)

yr2 = close_data[700] - close_data[730]
print("GOOG diff from 2 years: ", yr2)

yr3 = close_data[1065] - close_data[1095]
print("GOOG diff from 3 years: ", yr3)


points = 0
if(avg > month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if(day < month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if (yr > 0 and yr2 > 0 and yr3 > 0):
    points = points + 2
    print (points)
elif ((yr > 0 and yr2 > 0) or (yr2 > 0 and yr3 > 0) or (yr > 0 and yr3 > 0)):
    points = points + 1
    print (points)
elif (yr > 0 or yr2 > 0 or yr3 >0):
    print("null")
else:
    points = points - 1
    print (points)
    
    
print ("total",points)
if points > 0:
    print("buy GOOG")
elif points < 0:
    print("sell GOOG")
else:
    print("hold GOOG")
# Out:
# GOOG 100 day average: 2795.114000000001
# GOOG 30 day average: 2825.5856666666673
# GOOG diff from last year:  9.199999999999818
# GOOG diff from 2 years:  39.070000000000164
# GOOG diff from 3 years:  -12.449999999999932
# -1
# -2
# -1
# total -1
# sell GOOG

# %% [markdown]
# ## Testing Apple

# %%
data, meta_data = ts.get_daily(symbol='AAPL', outputsize='full')

close_data = data['4. close']

day = close_data[1]

i=1
avg = 0
while i<100:
    avg = close_data[i] + avg
    i = i+1
avg = avg/100
print("AAPL 100 day average:", avg)


i=1
month = 0
while i<30:
    month = close_data[i] + month
    i = i+1
month = month/30
print("AAPL 30 day average:", month)


yr = close_data[335] - close_data[365]
print("AAPL diff from last year: ", yr)
yr2 = close_data[700] - close_data[730]
print("AAPL diff from 2 years: ", yr2)

yr3 = close_data[1065] - close_data[1095]
print("AAPL diff from 3 years: ", yr3)


points = 0
if(avg > month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if(day < month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if (yr > 0 and yr2 > 0 and yr3 > 0):
    points = points + 2
    print (points)
elif ((yr > 0 and yr2 > 0) or (yr2 > 0 and yr3 > 0) or (yr > 0 and yr3 > 0)):
    points = points + 1
    print (points)
elif (yr > 0 or yr2 > 0 or yr3 >0):
    print("null")
else:
    points = points - 1
    print (points)
    
    
    
print ("total",points)
if points > 0:
    print("buy AAPL")
elif points < 0:
    print("sell AAPL")
else:
    print("hold AAPL")
# Out:
# AAPL 100 day average: 147.40940000000006
# AAPL 30 day average: 148.383
# AAPL diff from last year:  73.72000000000003
# AAPL diff from 2 years:  20.42999999999998
# AAPL diff from 3 years:  12.0
# -1
# -2
# 0
# total 0
# hold AAPL

# %% [markdown]
# ## Testing Netflix

# %%
data, meta_data = ts.get_daily(symbol='NFLX', outputsize='full')

close_data = data['4. close']

day = close_data[1]

i=1
avg = 0
while i<100:
    avg = close_data[i] + avg
    i = i+1
avg = avg/100
print("NFLX 100 day average:", avg)


i=1
month = 0
while i<30:
    month = close_data[i] + month
    i = i+1
month = month/30
print("NFLX 30 day average:", month)


yr = close_data[335] - close_data[365]
print("NFLX diff from last year: ", yr)

yr2 = close_data[700] - close_data[730]
print("NFLX diff from 2 years: ", yr2)


yr3 = close_data[1065] - close_data[1095]
print("NFLX diff from 3 years: ", yr3)


points = 0
if(avg > month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if(day < month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if (yr > 0 and yr2 > 0 and yr3 > 0):
    points = points + 2
    print (points)
elif ((yr > 0 and yr2 > 0) or (yr2 > 0 and yr3 > 0) or (yr > 0 and yr3 > 0)):
    points = points + 1
    print (points)
elif (yr > 0 or yr2 > 0 or yr3 >0):
    print("null")
else:
    points = points - 1
    print (points)
    
    
    
print ("total",points)
if points > 0:
    print("buy NFLX")
elif points < 0:
    print("sell NFLX")
else:
    print("hold NFLX")
# Out:
# NFLX 100 day average: 590.5224000000002
# NFLX 30 day average: 644.0393333333333
# NFLX diff from last year:  35.85000000000002
# NFLX diff from 2 years:  39.25
# NFLX diff from 3 years:  -2.299999999999983
# -1
# 0
# 1
# total 1
# buy NFLX

# %% [markdown]
# ## Testing AMZN

# %%
data, meta_data = ts.get_daily(symbol='AMZN', outputsize='full')

close_data = data['4. close']

day = close_data[1]

i=1
avg = 0
while i<100:
    avg = close_data[i] + avg
    i = i+1
avg = avg/100
print("AMZN 100 day average:", avg)


i=1
month = 0
while i<30:
    month = close_data[i] + month
    i = i+1
month = month/30
print("AMZN 30 day average:", month)


yr = close_data[335] - close_data[365]
print("AMZN diff from last year: ", yr)

yr2 = close_data[700] - close_data[730]
print("AMZN diff from 2 years: ", yr2)


yr3 = close_data[1065] - close_data[1095]
print("AMZN diff from 3 years: ", yr3)


points = 0
if(avg > month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if(day < month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if (yr > 0 and yr2 > 0 and yr3 > 0):
    points = points + 2
    print (points)
elif ((yr > 0 and yr2 > 0) or (yr2 > 0 and yr3 > 0) or (yr > 0 and yr3 > 0)):
    points = points + 1
    print (points)
elif (yr > 0 or yr2 > 0 or yr3 >0):
    print("null")
else:
    points = points - 1
    print (points)
    
    
    
print ("total",points)
if points > 0:
    print("buy AMZN")
elif points < 0:
    print("sell AMZN")
else:
    print("hold AMZN")
# Out:
# AMZN 100 day average: 3389.6027000000004
# AMZN 30 day average: 3366.406666666667
# AMZN diff from last year:  440.62000000000035
# AMZN diff from 2 years:  -23.220000000000027
# AMZN diff from 3 years:  -42.07999999999993
# 1
# 0
# null
# total 0
# hold AMZN

# %% [markdown]
# ## Testing WMT

# %%
data, meta_data = ts.get_daily(symbol='WMT', outputsize='full')

close_data = data['4. close']

day = close_data[1]

i=1
avg = 0
while i<100:
    avg = close_data[i] + avg
    i = i+1
avg = avg/100
print("WMT 100 day average:", avg)


i=1
month = 0
while i<30:
    month = close_data[i] + month
    i = i+1
month = month/30
print("WMT 30 day average:", month)


yr = close_data[335] - close_data[365]
print("WMT diff from last year: ", yr)

yr2 = close_data[700] - close_data[730]
print("WMT diff from 2 years: ", yr2)

yr3 = close_data[1065] - close_data[1095]
print("WMT diff from 3 years: ", yr3)


points = 0
if(avg > month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if(day < month):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if (yr > 0 and yr2 > 0 and yr3 > 0):
    points = points + 2
    print (points)
elif ((yr > 0 and yr2 > 0) or (yr2 > 0 and yr3 > 0) or (yr > 0 and yr3 > 0)):
    points = points + 1
    print (points)
elif (yr > 0 or yr2 > 0 or yr3 >0):
    print("null")
else:
    points = points - 1
    print (points)
    
    
    
print ("total",points)
if points > 0:
    print("buy WMT")
elif points < 0:
    print("sell WMT")
else:
    print("hold WMT")
# Out:
# WMT 100 day average: 143.4098
# WMT 30 day average: 141.81066666666666
# WMT diff from last year:  8.740000000000009
# WMT diff from 2 years:  4.160000000000011
# WMT diff from 3 years:  -0.730000000000004
# 1
# 2
# 3
# total 3
# buy WMT
