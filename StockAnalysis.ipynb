# %% [markdown]
# # Stock Analysis

# %% [markdown]
# ### setting up resued code

# %%
#pip install alpha_vantage

# %%
import pandas as pd
from alpha_vantage.timeseries import TimeSeries

# %%
api_key = 'JOAOIVTNEKIG83KH'
ts = TimeSeries(key=api_key, output_format='pandas')

# %% [markdown]
# ## Overall Idea
# I will use the basic idea of buy low sell high
#
# in order to do that I will get the average closing price from the last 100 days, the last 30 days and last day on the market. I will use these 3 data points as markers to see how the stock is doing.
#
# There are 3 possible outcomes:
#
# - If the 100 day average is greater than the 30 day average I assume it will go up and I will buy when it is low
# - If the 100 day average is lower than the 30 day average and the last days closing price was up I assume it is too high and the stock will come down so I will sell high
# - If the 30 day average is higher than the 100 day average but the last day was below the 30 day average I cant conclude much so I will either hold if i have it or wait another day.
#
#
# ### week 2
#
# I changed my analysis section of my code to work off points now.
# - If the 100 day average is higher than the month average I give the stock a point otherwise I take a point away.
# - if the last day is lower than the month average I give the stock a point otherwise I take a point away.
# - if the stock grew last year within this month I give the stock a point otherwise I take a point way.
# - if the points are positive I buy if they are negative I sell if they are nutural I do nothing.
#
# I am also taking into consideration Walmart stock

# %% [markdown]
# ### Testing NKE

# %%
data, meta_data = ts.get_daily(symbol='NKE', outputsize='full')

close_data = data['4. close']

NKEday = close_data[1]

i=1
NKEavg = 0
while i<100:
    NKEavg = close_data[i] + NKEavg
    i = i+1
NKEavg = NKEavg/100
print("Nike 100 day average:", NKEavg)


i=1
NKEmonth = 0
while i<30:
    NKEmonth = close_data[i] + NKEmonth
    i = i+1
NKEmonth = NKEmonth/30
print("Nike 30 day average:", NKEmonth)


NKEyr = close_data[335] - close_data[365]
print("Nike diff from last year: ", NKEyr)

points = 0
if(NKEavg > NKEmonth):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if(NKEday < NKEmonth):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
if (NKEyr > 0):
    points = points + 1
    print (points)
else:
    points = points - 1
    print (points)
    
    
print ("total",points)
if points > 0:
    print("buy NKE")
elif points < 0:
    print("sell NKE")
else:
    print("hold NKE")
# Out:
# Nike 100 day average: 161.67290000000003
# Nike 30 day average: 161.77533333333335
# Nike diff from last year:  -2.0700000000000074
# -1
# -2
# -3
# total -3
# sell NKE

# %% [markdown]
# ### Testing GOOG

# %%
data, meta_data = ts.get_daily(symbol='GOOG', outputsize='full')

close_data = data['4. close']

GOOGday = close_data[1]

i = 1
GOOGavg = 0
while i < 100:
    GOOGavg = close_data[i] + GOOGavg
    i = i + 1
GOOGavg = GOOGavg / 100
print("Google 100 day average:", GOOGavg)

i = 1
GOOGmonth = 0
while i < 30:
    GOOGmonth = close_data[i] + GOOGmonth
    i = i + 1
GOOGmonth = GOOGmonth / 30
print("Google 30 day average:", GOOGmonth)

GOOGyr = close_data[335] - close_data[365]
print("Google diff from last year:", GOOGyr)

points = 0
if (GOOGavg > GOOGmonth):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

if (GOOGday < GOOGmonth):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

if (GOOGyr > 0):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

print("total", points)
if points > 0:
    print("buy GOOG")
elif points < 0:
    print("sell GOOG")
else:
    print("hold GOOG")
# Out:
# Google 100 day average: 2781.2500000000014
# Google 30 day average: 2820.6370000000015
# Google diff from last year: 79.29999999999995
# -1
# -2
# -1
# total -1
# sell GOOG

# %% [markdown]
# ## Testing Apple

# %%
data, meta_data = ts.get_daily(symbol='AAPL', outputsize='full')

close_data = data['4. close']

AAPLday = close_data[1]

i=1
AAPLavg = 0
while i<100:
    AAPLavg = close_data[i] + AAPLavg
    i = i+1
AAPLavg = AAPLavg/100
print("AAPL 100 day average:", AAPLavg)


i=1
AAPLmonth = 0
while i<30:
    AAPLmonth = close_data[i] + AAPLmonth
    i = i+1
AAPLmonth = AAPLmonth/30
print("AAPL 30 day average:", AAPLmonth)


AAPLyr = close_data[335] - close_data[365]
print("Apple diff from last year:", AAPLyr)

points = 0
if (AAPLavg > AAPLmonth):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

if (AAPLday < AAPLmonth):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

if (AAPLyr > 0):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

print("total", points)
if points > 0:
    print("buy AAPL")
elif points < 0:
    print("sell AAPL")
else:
    print("hold AAPL")
# Out:
# AAPL 100 day average: 146.54940000000005
# AAPL 30 day average: 145.85333333333338
# Apple diff from last year: 28.08000000000004
# 1
# 0
# 1
# total 1
# buy AAPL

# %% [markdown]
# ## Testing Netflix

# %%
data, meta_data = ts.get_daily(symbol='NFLX', outputsize='full')

close_data = data['4. close']

NFLXday = close_data[1]

i=1
NFLXavg = 0
while i<100:
    NFLXavg = close_data[i] + NFLXavg
    i = i+1
NFLXavg = NFLXavg/100
print("NFLX 100 day average:", NFLXavg)


i=1
NFLXmonth = 0
while i<30:
    NFLXmonth = close_data[i] + NFLXmonth
    i = i+1
NFLXmonth = NFLXmonth/30
print("NFLX 30 day average:", NFLXmonth)


NFLXyr = close_data[335] - close_data[365]
print("NFLX diff from last year: ", NFLXyr)

points = 0
if (NFLXavg > NFLXmonth):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

if (NFLXday < NFLXmonth):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

if (NFLXyr > 0):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

print("total", points)
if points > 0:
    print("buy NFLX")
elif points < 0:
    print("sell NFLX")
else:
    print("hold NFLX")
# Out:
# NFLX 100 day average: 584.8549
# NFLX 30 day average: 641.2646666666666
# NFLX diff from last year:  48.35000000000002
# -1
# -2
# -1
# total -1
# sell NFLX

# %% [markdown]
# ## Testing AMZN

# %%
data, meta_data = ts.get_daily(symbol='AMZN', outputsize='full')

close_data = data['4. close']

AMZNday = close_data[1]

i=1
AMZNavg = 0
while i<100:
    AMZNavg = close_data[i] + AMZNavg
    i = i+1
AMZNavg = AMZNavg/100
print("AMZN 100 day average:", AMZNavg)


i=1
AMZNmonth = 0
while i<30:
    AMZNmonth = close_data[i] + AMZNmonth
    i = i+1
AMZNmonth = AMZNmonth/30
print("AMZN 30 day average:", AMZNmonth)


AMZNyr = close_data[335] - close_data[365]
print("AMZN diff from last year: ", AMZNyr)

points = 0
if (AMZNavg > AMZNmonth):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

if (AMZNday < AMZNmonth):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

if (AMZNyr > 0):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

print("total", points)
if points > 0:
    print("buy AMZN")
elif points < 0:
    print("sell AMZN")
else:
    print("hold AMZN")
# Out:
# AMZN 100 day average: 3399.0618
# AMZN 30 day average: 3346.9900000000002
# AMZN diff from last year:  418.2600000000002
# 1
# 0
# 1
# total 1
# buy AMZN

# %% [markdown]
# ## Testing WMT

# %%
data, meta_data = ts.get_daily(symbol='WMT', outputsize='full')

close_data = data['4. close']

WMTday = close_data[1]

i=1
WMTavg = 0
while i<100:
    WMTavg = close_data[i] + WMTavg
    i = i+1
WMTavg = WMTavg/100
print("WMT 100 day average:", WMTavg)


i=1
WMTmonth = 0
while i<30:
    WMTmonth = close_data[i] + WMTmonth
    i = i+1
WMTmonth = WMTmonth/30
print("WMT 30 day average:", WMTmonth)

WMTyr = close_data[335] - close_data[365]
print("WMT diff from last year:", WMTyr)

points = 0
if (WMTavg > WMTmonth):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

if (WMTday < WMTmonth):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

if (WMTyr > 0):
    points = points + 1
    print(points)
else:
    points = points - 1
    print(points)

print("total", points)
if points > 0:
    print("buy WMT")
elif points < 0:
    print("sell WMT")
else:
    print("hold WMT")
# Out:
# WMT 100 day average: 143.29369999999997
# WMT 30 day average: 141.84233333333333
# WMT diff from last year: 11.039999999999992
# 1
# 0
# 1
# total 1
# buy WMT
